# %% [markdown]
# # Data Analysis, Module 2, Week 2

# %% [markdown]
# I am somewhat confused.
# Were the assignments in week 2 not submitted as their own repositories?
# i.e. learning_plots, spotify_eda
#
# Coding questions from the quiz are included below.

# %% [markdown]
# ## Question 7
#
# Create a Bar Plot - The title and axes must match the directions exactly/are case sensitive. Do not add anything you do not need.

# %%
import pandas as pd
import matplotlib.pyplot as plt

data = {
    "genre": ["Pop", "Rock", "Hip-Hop", "Electronic"],
    "streams": [120, 90, 150, 70]
}

df = pd.DataFrame(data)

# Write code below to create and display a bar plot showing streams by genre
# Label the axes "Genre"(x) and "Streams"(y)
# add a title "Streams by Genre"

#YOUR CODE GOES HERE!! NOTE: If the axes and title labels do not match exactly, the code will not pass. Keep this simple do not do more than is required. 

# REMEMBER TO EXECUTE THE CODE BEFORE MOVING ON TO THE NEXT QUESTION, THIS ALLOWS YOU TO CHECK IF YOU GOT IT RIGHT

plt.bar(df['genre'], df['streams'])

plt.xlabel("Genre")
plt.ylabel("Streams by Genre")
plt.title("Streams by Genre")

plt.show()

# %% [markdown]
# ## Question 8
#
# Create a Histogram - The title and axes must match the directions exactly/are case sensitive. Do not add anything you do not need.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "duration_ms": [210000, 180000, 240000, 300000, 190000, 220000, 260000, 250000]
})

# Write code below to create and display a histogram showing the distribution of song durations
# Use 5 bins, 
# add a title "Distribution of Song Durations"
# label the axes "Duration" (x) and "Count" (y)

#YOUR CODE GOES HERE!! NOTE: If the axes and title labels do not match exactly, the code will not pass. Keep this simple do not do more than is required. 

# REMEMBER TO EXECUTE THE CODE BEFORE MOVING ON TO THE NEXT QUESTION, THIS ALLOWS YOU TO CHECK IF YOU GOT IT RIGHT

df.hist(bins=5)
plt.xlabel("Duration")
plt.ylabel("Count")
plt.title("Distribution of Song Duration")

plt.show()

# %% [markdown]
# ## Question 9
#
# Create a Scatter Plot - The title and axes must match the directions exactly/are case sensitive. Do not add anything you do not need.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "energy": [0.6, 0.8, 0.5, 0.9, 0.7, 0.65],
    "valence": [0.5, 0.7, 0.4, 0.8, 0.6, 0.55]
})

# Write code below to create and display a scatter plot of energy vs valence
# Label the axes "Energy" (x) and "Valence" (y)
# Title the chart "Energy vs Valence"

#YOUR CODE GOES HERE!! NOTE: If the axes and title labels do not match exactly, the code will not pass. Keep this simple do not do more than is required. 

# REMEMBER TO EXECUTE THE CODE BEFORE MOVING ON TO THE NEXT QUESTION, THIS ALLOWS YOU TO CHECK IF YOU GOT IT RIGHT

plt.scatter(df['energy'],df['valence'])
plt.xlabel("Energy")
plt.ylabel("Valence")
plt.title("Energy vs Valence")

plt.show()
